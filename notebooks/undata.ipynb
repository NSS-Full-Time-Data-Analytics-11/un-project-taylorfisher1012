# %% [markdown]
# Guided exploration of UN data project

# %% [markdown]
# Importing necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 0        Afghanistan  2020  1970.560169              NaN
# 1        Afghanistan  2019  2065.036235              NaN
# 2        Afghanistan  2018  2033.804389              NaN
# 3        Afghanistan  2017  2058.400221              NaN
# 4        Afghanistan  2016  2057.067978              NaN
# ...              ...   ...          ...              ...
# 7171        Zimbabwe  1994  2603.927369              NaN
# 7172        Zimbabwe  1993  2420.092791              NaN
# 7173        Zimbabwe  1992  2437.152908              NaN
# 7174        Zimbabwe  1991  2733.696626              NaN
# 7175        Zimbabwe  1990  2652.129209              NaN
#
# [7176 rows x 4 columns]

# %%
#Problem 5: How many rows and columns are in `gdp_df`? What are the data types of each column?
type(gdp_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ANS: Question 5. There are 7176 row and 4 columns in the gdp_df and it is a dataframe

# %%
#Problem 6: Drop the 'Value Footnote' column
gdp_df_percapita = gdp_df.drop(columns = ['Value Footnotes'])

# %%
gdp_df_percapita
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2020  1970.560169
# 1        Afghanistan  2019  2065.036235
# 2        Afghanistan  2018  2033.804389
# 3        Afghanistan  2017  2058.400221
# 4        Afghanistan  2016  2057.067978
# ...              ...   ...          ...
# 7171        Zimbabwe  1994  2603.927369
# 7172        Zimbabwe  1993  2420.092791
# 7173        Zimbabwe  1992  2437.152908
# 7174        Zimbabwe  1991  2733.696626
# 7175        Zimbabwe  1990  2652.129209
#
# [7176 rows x 3 columns]

# %%
#Problem 6 cont: Rename the remaining three columns to 'Country', 'Year', 'GDP_Per_Capita'
gdp_df_percapita.columns = ['Country', 'Year', 'GDP_Per_Capita']

# %%
gdp_df_percapita
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2020     1970.560169
# 1     Afghanistan  2019     2065.036235
# 2     Afghanistan  2018     2033.804389
# 3     Afghanistan  2017     2058.400221
# 4     Afghanistan  2016     2057.067978
# ...           ...   ...             ...
# 7171     Zimbabwe  1994     2603.927369
# 7172     Zimbabwe  1993     2420.092791
# 7173     Zimbabwe  1992     2437.152908
# 7174     Zimbabwe  1991     2733.696626
# 7175     Zimbabwe  1990     2652.129209
#
# [7176 rows x 3 columns]

# %%
#Problem 7: How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?
gdp_df_percapita.Country.value_counts()
# Out:
# Country
# Least developed countries: UN classification    31
# Niger                                           31
# Middle East & North Africa (IDA & IBRD)         31
# Middle income                                   31
# Mongolia                                        31
#                                                 ..
# Kosovo                                          13
# Turks and Caicos Islands                        10
# Sint Maarten (Dutch part)                       10
# Somalia                                          8
# Djibouti                                         8
# Name: count, Length: 242, dtype: int64

# %%
gdp_df_percapita.Year.value_counts()
# Out:
# Year
# 2018    242
# 2017    242
# 2016    242
# 2015    242
# 2014    242
# 2013    242
# 2019    241
# 2020    240
# 2012    240
# 2011    240
# 2010    239
# 2009    239
# 2008    238
# 2007    237
# 2006    237
# 2004    236
# 2005    236
# 2003    235
# 2002    235
# 2001    234
# 2000    233
# 1999    227
# 1998    226
# 1997    226
# 1996    222
# 1995    222
# 1994    211
# 1993    209
# 1992    208
# 1991    207
# 1990    206
# Name: count, dtype: int64

# %%
gdp_df_2020 = gdp_df_percapita[gdp_df_percapita["Year"] == 2020]
gdp_df_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
#Question 8: In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?
sns.distplot(a = gdp_df_2020['GDP_Per_Capita'], hist = True, kde = False, rug = False)
# Out:
# C:\Users\fisht\AppData\Local\Temp\ipykernel_3112\2654542847.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a = gdp_df_2020['GDP_Per_Capita'], hist = True, kde = False, rug = False)
# <Axes: xlabel='GDP_Per_Capita'>

# %%
#Desity Plot

sns.kdeplot(gdp_df_2020['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
#Boxplot

sns.boxplot(x = gdp_df_2020['Year'], y = gdp_df_percapita['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Violin Plot
sns.violinplot(x = gdp_df_2020['Year'], y = gdp_df_percapita['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Problem 9: What was the median GDP per capita value in 2020
gdp_df_2020 = gdp_df_percapita[gdp_df_percapita["Year"] == 2020]
gdp_df_2020['GDP_Per_Capita'].median()
# Out:
# 12908.9374056206

# %%
gdp_df_2020
# Out:
#                           Country  Year  GDP_Per_Capita
# 0                     Afghanistan  2020     1970.560169
# 19    Africa Eastern and Southern  2020     3491.978104
# 50     Africa Western and Central  2020     4021.293919
# 81                        Albania  2020    13253.733337
# 112                       Algeria  2020    10735.382539
# ...                           ...   ...             ...
# 7025                      Vietnam  2020    10338.270543
# 7056           West Bank and Gaza  2020     5402.538773
# 7083                        World  2020    16269.969854
# 7114                       Zambia  2020     3277.816510
# 7145                     Zimbabwe  2020     2134.555461
#
# [240 rows x 3 columns]

# %%
#Problem 10: For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010 and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots
#boxplot, barplot, scatterplot, scatterplot with trend line. Comment on what you observe has happened to GDP over time and the relative strengths and weaknesses of each type of plot. 

gdp_decades = gdp_df_percapita[gdp_df_percapita["Year"].isin([1990, 2000, 2010, 2020])]
gdp_decades
#Boxplot
sns.boxplot(x=gdp_decades["Year"], y=gdp_decades["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Barplot
sns.barplot(x=gdp_decades["Year"], y=gdp_decades["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Scatterplot
sns.regplot(x=gdp_decades["Year"], y=gdp_decades["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
#Problem 11: Which country was the first to have a GDP per capita greater $100,000
large_gdp = gdp_df_percapita[gdp_df_percapita['GDP_Per_Capita']>100000] 
large_gdp.nsmallest(1,'Year')
# Out:
#                    Country  Year  GDP_Per_Capita
# 6838  United Arab Emirates  1990   111454.055665

# %%
#Problem 12: Which country has the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.
largest_gdp_2020 = gdp_df_2020.nlargest(1,'GDP_Per_Capita')
largest_gdp = gdp_df_percapita[gdp_df_percapita['Country']==largest_gdp_2020.iloc[0][0]]
plt.plot(largest_gdp['Year'], largest_gdp['GDP_Per_Capita'])
plt.title('GDP for Luxenberg')
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
# Out:
# Text(0, 0.5, 'GDP Per Capita')

# %%
#Problem 13: Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the time span of the dataset
smallest_gdp_2020 = gdp_df_2020.nsmallest(1,'GDP_Per_Capita')
smallest_gdp = gdp_df_percapita[gdp_df_percapita['Country']==smallest_gdp_2020.iloc[0][0]]
plt.plot(smallest_gdp['Year'], smallest_gdp['GDP_Per_Capita'])
plt.title('GDP for Burundi')
plt.xlabel('Year')
plt.ylabel('GDP Per Capita')
# Out:
# Text(0, 0.5, 'GDP Per Capita')

# %%
#Problem 14: Read ini the internet dataset imto a DataFra
pd.read_csv('../data/internet_use.csv', sep ='delimiter')
# Out:
# C:\Users\fisht\AppData\Local\Temp\ipykernel_3112\277090573.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv('../data/internet_use.csv', sep ='delimiter')
#      "Country or Area","Year","Value","Value Footnotes"
# 0                        "Afghanistan","2014","6.39",""
# 1                         "Afghanistan","2013","5.9",""
# 2            "Afghanistan","2012","5.45454545454545",""
# 3                           "Afghanistan","2011","5",""
# 4                           "Afghanistan","2010","4",""
# ...                                                 ...
# 4679                           "176","NTIA/CPS survey."
# 4680  "177","Pew Internet Project, "Internet, Broadb...
# 4681  "178","Estimated based on Survey's results. Po...
# 4682             "179","Preliminary. Country estimate."
# 4683  "180","The methodology used to estimated the f...
#
# [4684 rows x 1 columns]

# %%
#Problem 15:Drop the 'Value Footnote' column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'

# %%
#Problem 16: Look at the number of observations in this dataset per year. What do you notice?

# %%
#Probelm 17: What is the first year to have a non-zero internet users percentage?

# %%
#Problem 18: How does the distribution of internet users percent differ for 2000 to 2014

# %%
#Problem 19: For how many countries was the percentage of internet users below 5% in 2014

# %%
#Problem 20: Merge the two dataframes to one

# %%
#Problem 21: Find the three countries with the highest internet users percentage in 2014.

# %%
#Problem 22: Subset 'gdp_and_internet_use' to just the year 2014. Save this as a new dataframe named 'gdp_and_internet_use_2014'

# %%
#Problem 23: Create a plot which compares internet users percentage and GDP per capita for the year 2014. What do you notice from this plot. If you see any unusual points, investigate them.
